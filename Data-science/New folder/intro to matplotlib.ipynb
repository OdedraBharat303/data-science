# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(.1,.5,11)

# %%
x
# Out:
# array([0.1 , 0.14, 0.18, 0.22, 0.26, 0.3 , 0.34, 0.38, 0.42, 0.46, 0.5 ])

# %%
y=x*y

# %%
y
# Out:
# array([0.001   , 0.002744, 0.005832, 0.010648, 0.017576, 0.027   ,
#        0.039304, 0.054872, 0.074088, 0.097336, 0.125   ])

# %%
plt.plot(x,y,'m')
plt.title("jai ho")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'m')
plt.title("jai ho")
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1,2,2)
plt.plot(y,x,'m')
plt.title("jai ho")
plt.xlabel("x")
plt.ylabel("y")

plt.tight_layout()

plt.show()
