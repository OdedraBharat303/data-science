# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from decimal import Decimal
# %matplotlib inline

# %%
pl=pd.read_csv('D:\\datasets\\googleplaystore.csv')

# %%
pl
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
len(pl)
# Out:
# 10779

# %%
pl.ndim
# Out:
# 2

# %%
pl.shape
# Out:
# (10779, 13)

# %%
pl.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
pl.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
pl.isna().count()
# Out:
# App               10779
# Category          10779
# Rating            10779
# Reviews           10779
# Size              10779
# Installs          10779
# Type              10779
# Price             10779
# Content Rating    10779
# Genres            10779
# Last Updated      10779
# Current Ver       10779
# Android Ver       10779
# dtype: int64

# %%
plt.figure(figsize=(10,5))
pl.groupby('Rating')['App'].count().tail(20).plot(kind='bar')

# %%
len(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8f92e5cd480a> in <module>()
# ----> 1 len(m)
#
# NameError: name 'm' is not defined

# %%
s=pl.Category.value_counts().head(10)

# %%
s
# Out:
# FAMILY             1953
# GAME               1135
# TOOLS               836
# MEDICAL             463
# BUSINESS            459
# PRODUCTIVITY        424
# PERSONALIZATION     387
# COMMUNICATION       386
# SPORTS              384
# LIFESTYLE           378
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(10,10),facecolor='black')
plt.pie(s[0:10],labels=['FAMILY','GAME','TOOLS','MEDICAL','BUSINESS','PRODUCT','PERSIONAL','COMMUNICATION','SPORT','LIFESTYLE'],autopct='%.f%%',startangle=20,explode=[0.02,0.02,0.02,0.01,0.01,0,0,0,0,0],textprops={'fontsize':12,'color':'w'})
plt.show()

# %%
pl
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
pl.Type.value_counts()
# Out:
# Free    9986
# Paid     792
# Name: Type, dtype: int64

# %%
pl.Price.value_counts()
# Out:
# 0           9987
# $0.99        147
# $2.99        127
# $1.99         72
# $4.99         71
# $3.99         63
# $1.49         44
# $5.99         30
# $2.49         26
# $9.99         21
# $6.99         13
# $399.99       12
# $14.99        11
# $4.49          9
# $7.99          7
# $24.99         7
# $29.99         7
# $19.99         6
# $5.49          6
# $3.49          6
# $12.99         5
# $6.49          5
# $11.99         5
# $8.99          5
# $10.00         3
# $16.99         3
# $2.00          3
# $1.00          3
# $39.99         2
# $79.99         2
#             ...
# $3.08          1
# $3.88          1
# $2.90          1
# $18.99         1
# $1.75          1
# $1.59          1
# $46.99         1
# $299.99        1
# $74.99         1
# $1.96          1
# $109.99        1
# $200.00        1
# $394.99        1
# $1.50          1
# $2.56          1
# $379.99        1
# $14.00         1
# $2.50          1
# $15.99         1
# $15.46         1
# $1.97          1
# ...
