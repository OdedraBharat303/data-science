# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s= pd.Series ([1,2,3,54,4,5,5,np.nan,88])

# %%
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3    54.0
# 4     4.0
# 5     5.0
# 6     5.0
# 7     NaN
# 8    88.0
# dtype: float64

# %%
a=pd.Series({1:"bharat",2:"jayesh",3:"kailash"})

# %%
a
# Out:
# 1     bharat
# 2     jayesh
# 3    kailash
# dtype: object

# %%
data = {
    'Name':['bharat','keyur','nikhil','ajay'],
    'Age':[24,22,23,21],
    'Phy':[34,54,65,65],
    'Chem':[34,54,23,67],
    
    'Math':[87,67,56,45]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age  Phy  Chem  Math
# 0  bharat   24   34    34    87
# 1   keyur   22   54    54    67
# 2  nikhil   23   65    23    56
# 3    ajay   21   65    67    45

# %%
df['total']=df['Phy']+df['Chem']+df['Math']

# %%
df
# Out:
#      Name  Age  Phy  Chem  Math  total
# 0  bharat   24   34    34    87    155
# 1   keyur   22   54    54    67    175
# 2  nikhil   23   65    23    56    144
# 3    ajay   21   65    67    45    177

# %%
df['avg']=df['total']//3

# %%
df
# Out:
#      Name  Age  Phy  Chem  Math  total  avg
# 0  bharat   24   34    34    87    155   51
# 1   keyur   22   54    54    67    175   58
# 2  nikhil   23   65    23    56    144   48
# 3    ajay   21   65    67    45    177   59

# %%
data
# Out:
# {'Name': ['bharat', 'keyur', 'nikhil', 'ajay'],
#  'Age': [24, 22, 23, 21],
#  'Phy': [34, 54, 65, 65],
#  'Chem': [34, 54, 23, 67],
#  'Math': [87, 67, 56, 45]}

# %%
data
# Out:
# {'Name': ['bharat', 'keyur', 'nikhil', 'ajay'],
#  'Age': [24, 22, 23, 21],
#  'Phy': [34, 54, 65, 65],
#  'Chem': [34, 54, 23, 67],
#  'Math': [87, 67, 56, 45]}

# %%
ndata=[['baharat',3154638474],
      ['ajay',3546546531],
      ['jayesh',6416554]]

# %%
column=['name','contact']
index=['a','b','c']

# %%
dff=pd.DataFrame(ndata,columns=column,index=index)

# %%
dff
# Out:
#       name     contact
# a  baharat  3154638474
# b     ajay  3546546531
# c   jayesh     6416554

# %%
dff
# Out:
#       name     contact
# a  baharat  3154638474
# b     ajay  3546546531
# c   jayesh     6416554

# %%
date=pd.date_range('20181105',periods=3)

# %%
date
# Out:
# DatetimeIndex(['2018-11-05', '2018-11-06', '2018-11-07'], dtype='datetime64[ns]', freq='D')

# %%
dff.index=date

# %%
dff
# Out:
#                name     contact
# 2018-11-05  baharat  3154638474
# 2018-11-06     ajay  3546546531
# 2018-11-07   jayesh     6416554

# %%
df=pd.DataFrame(np.random.randn(4,5),columns=list('ABCDE'),index=pd.date_range('20181104',periods=4))

# %%
df
# Out:
#                    A         B         C         D         E
# 2018-11-04  0.135602  0.659115 -1.892338  0.984388  1.056710
# 2018-11-05  0.358077 -0.039009  2.713546  1.651824  0.353656
# 2018-11-06 -0.762548  0.451694 -1.082992 -0.066913  0.715668
# 2018-11-07  0.665814 -0.224089  0.870713 -1.492710 -0.732306

# %%
plt.figure(figsize=(10,8),facecolor='gray')
plt.plot(df)
plt.show()

# %%
df[['C','D']].plot()

# %%
plt.plot(df['A'],df['C'])

# %%
df
# Out:
#                    A         B         C         D         E
# 2018-11-04  0.135602  0.659115 -1.892338  0.984388  1.056710
# 2018-11-05  0.358077 -0.039009  2.713546  1.651824  0.353656
# 2018-11-06 -0.762548  0.451694 -1.082992 -0.066913  0.715668
# 2018-11-07  0.665814 -0.224089  0.870713 -1.492710 -0.732306

# %%
df[1:2]
# Out:
#                    A         B         C         D         E
# 2018-11-05  0.358077 -0.039009  2.713546  1.651824  0.353656

# %%
df[0:2]
# Out:
#                    A         B         C         D         E
# 2018-11-04  0.135602  0.659115 -1.892338  0.984388  1.056710
# 2018-11-05  0.358077 -0.039009  2.713546  1.651824  0.353656

# %%
df.loc

# %%
df
# Out:
#                    A         B         C         D         E
# 2018-11-04  0.135602  0.659115 -1.892338  0.984388  1.056710
# 2018-11-05  0.358077 -0.039009  2.713546  1.651824  0.353656
# 2018-11-06 -0.762548  0.451694 -1.082992 -0.066913  0.715668
# 2018-11-07  0.665814 -0.224089  0.870713 -1.492710 -0.732306

# %%
dff
# Out:
#                name     contact
# 2018-11-05  baharat  3154638474
# 2018-11-06     ajay  3546546531
# 2018-11-07   jayesh     6416554

# %%
hb=pd.read_csv('D:\datasets\h1b.csv')

# %%
hb
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
hb.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
hb.tail()
# Out:
#          Unnamed: 0 CASE_STATUS EMPLOYER_NAME SOC_NAME JOB_TITLE  \
# 3002453     3002454         NaN           NaN      NaN       NaN
# 3002454     3002455         NaN           NaN      NaN       NaN
# 3002455     3002456         NaN           NaN      NaN       NaN
# 3002456     3002457         NaN           NaN      NaN       NaN
# 3002457     3002458         NaN           NaN      NaN       NaN
#
#         FULL_TIME_POSITION  PREVAILING_WAGE  YEAR               WORKSITE  \
# 3002453                NaN              NaN   NaN          NYC, NEW YORK
# 3002454                NaN              NaN   NaN      SOUTH LAKE, TEXAS
# 3002455                NaN              NaN   NaN    CLINTON, NEW JERSEY
# 3002456                NaN              NaN   NaN  OWINGS MILL, MARYLAND
# 3002457                NaN              NaN   NaN       ALTANTA, GEORGIA
#
#                lon        lat
# 3002453 -74.005941  40.712784
# 3002454 -97.134178  32.941236
# 3002455 -74.909890  40.636768
# ...

# %%
hb.ndim
# Out:
# 2

# %%
hb.shape
# Out:
# (3002458, 11)

# %%
hb.dropna(inplace=True)

# %%
hb.shape
# Out:
# (2877765, 11)

# %%
len(hb)
# Out:
# 2877765

# %%
hb.drop('Unnamed: 0',axis=1,inplace=True)

# %%
hb.head(10)
# Out:
#             CASE_STATUS                                      EMPLOYER_NAME  \
# 0   CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1   CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2   CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3   CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4             WITHDRAWN                          PEABODY INVESTMENTS CORP.
# 5   CERTIFIED-WITHDRAWN                            BURGER KING CORPORATION
# 6   CERTIFIED-WITHDRAWN                   BT AND MK ENERGY AND COMMODITIES
# 7   CERTIFIED-WITHDRAWN                    GLOBO MOBILE TECHNOLOGIES, INC.
# 9             WITHDRAWN                          LESSARD INTERNATIONAL LLC
# 10  CERTIFIED-WITHDRAWN                                 H.J. HEINZ COMPANY
#
#                          SOC_NAME  \
# 0   BIOCHEMISTS AND BIOPHYSICISTS
# 1                CHIEF EXECUTIVES
# 2                CHIEF EXECUTIVES
# ...

# %%
hb.columns = [ 'casestatus', 'companies', 'socname', 'jobtitle',
       'ftposition', 'wages', 'year', 'worksite', 'lon',
       'lat']

# %%
hb
# Out:
#                   casestatus  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# 5        CERTIFIED-WITHDRAWN
# 6        CERTIFIED-WITHDRAWN
# 7        CERTIFIED-WITHDRAWN
# 9                  WITHDRAWN
# 10       CERTIFIED-WITHDRAWN
# 11       CERTIFIED-WITHDRAWN
# 13       CERTIFIED-WITHDRAWN
# 14       CERTIFIED-WITHDRAWN
# 15       CERTIFIED-WITHDRAWN
# 16       CERTIFIED-WITHDRAWN
# 17       CERTIFIED-WITHDRAWN
# 18                 CERTIFIED
# 19                 CERTIFIED
# 20       CERTIFIED-WITHDRAWN
# 21       CERTIFIED-WITHDRAWN
# 22                 CERTIFIED
# 23                 CERTIFIED
# 24       CERTIFIED-WITHDRAWN
# 25                 CERTIFIED
# 26       CERTIFIED-WITHDRAWN
# 27                 CERTIFIED
# 28                 CERTIFIED
# 29                 CERTIFIED
# 30                 CERTIFIED
# 31                 CERTIFIED
# ...                      ...
# ...
