# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://grras.com/page/gallery"

# %%
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Gallery - Grras Solutions Pvt. Ltd.</title>
# <meta content="Gallery of Grras solutions, Images of Classroom trainings, Workshop images of Grras, Events images of Grras solutions" name="keywords"/>
# <meta content="Memorable memories of Grras Solutions. See images of events, classroom labs, Seminars, Workshops and complete gallery.
# " name="description"/>
# <link href="https://grras.com/" rel="canonical"/>
# <meta content="Linux Training Institute, RedHat Training Center" name="classification"/>
# <meta content="Linux Training Institute, RedHat Training Center" name="copyright"/>
# <meta content="GRRAS Solution Pvt Ltd, Linux Training Institute, RedHat Training Center" name="author"/>
# <meta content="India" name="geography"/>
# <meta content="global" name="distribution"/>
# <meta content="en-us" name="language"/>
# ...

# %%
soup.findAll('img')
# Out:
# [<img alt="Grras Solutions Pvt. Ltd." class="img-responsive" src="https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60"/>,
#  <img alt="Memories of Grras Solutions" class="hide" onload='jQuery(".home-header").removeClass("hide");' src="https://grras.com/files/8npn6peg805reyhs09qb/banner.jpg?s=1400x600"/>,
#  <img alt="Gallery" class="img-responsive" src="https://grras.com/files/ahltuf4hthof364k4ecv/a2_img.jpg?s=1400x500"/>,
#  <img alt="Gallery" class="img-responsive" src="https://grras.com/files/l88zn88er07vqe5qgecl/b1_img.jpg?s=1400x500"/>,
#  <img alt="Master" class="img-responsive" src="https://grras.com/files/rrpe2og7rzbifmrgy6id/Akhilesh Jain.jpg?s=228x223" width="400px"/>,
#  <img alt="Master" class="img-responsive" src="https://grras.com/files/grfmu8lu6m7b7efchc4v/Gaurav Saluja.jpg?s=228x223" width="400px"/>,
#  <img alt="Master" class="img-responsive" src="https://grras.com/files/sgfzpjgly22kl1iqjcik/Rajat Goyal.jpg?s=228x223" width="400px"/>,
# ...

# %%
link = []
for var in soup.findAll('img'):
    print(var['src'])
    link.append(var['src'])
# Out:
# https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60
# https://grras.com/files/8npn6peg805reyhs09qb/banner.jpg?s=1400x600
# https://grras.com/files/ahltuf4hthof364k4ecv/a2_img.jpg?s=1400x500
# https://grras.com/files/l88zn88er07vqe5qgecl/b1_img.jpg?s=1400x500
# https://grras.com/files/rrpe2og7rzbifmrgy6id/Akhilesh Jain.jpg?s=228x223
# https://grras.com/files/grfmu8lu6m7b7efchc4v/Gaurav Saluja.jpg?s=228x223
# https://grras.com/files/sgfzpjgly22kl1iqjcik/Rajat Goyal.jpg?s=228x223
# https://grras.com/files/4exdjp9cyqmcwbrwennh/Ravi Sarswat.jpg?s=228x223
# https://grras.com/files/bg4wpv635w1kytpoj2w3/Rajesh Shah.jpg?s=228x223
# https://grras.com/files/1vvfe9uwacszycssqca2/Shiv Mohan.jpg?s=228x223
# https://grras.com/files/mkqdalaquvimuatvokhy/Nidhi Sharma.jpg?s=228x223
# https://grras.com/files/xcxagzwtcpm8xusgf9ga/Harshad Rana.jpg?s=228x223
# https://grras.com/files/z1t5x5siktlaf0ysxeaf/Sachin Yadav.jpg?s=228x223
# ...

# %%
link
# Out:
# ['https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60',
#  'https://grras.com/files/8npn6peg805reyhs09qb/banner.jpg?s=1400x600',
#  'https://grras.com/files/ahltuf4hthof364k4ecv/a2_img.jpg?s=1400x500',
#  'https://grras.com/files/l88zn88er07vqe5qgecl/b1_img.jpg?s=1400x500',
#  'https://grras.com/files/rrpe2og7rzbifmrgy6id/Akhilesh Jain.jpg?s=228x223',
#  'https://grras.com/files/grfmu8lu6m7b7efchc4v/Gaurav Saluja.jpg?s=228x223',
#  'https://grras.com/files/sgfzpjgly22kl1iqjcik/Rajat Goyal.jpg?s=228x223',
#  'https://grras.com/files/4exdjp9cyqmcwbrwennh/Ravi Sarswat.jpg?s=228x223',
#  'https://grras.com/files/bg4wpv635w1kytpoj2w3/Rajesh Shah.jpg?s=228x223',
#  'https://grras.com/files/1vvfe9uwacszycssqca2/Shiv Mohan.jpg?s=228x223',
#  'https://grras.com/files/mkqdalaquvimuatvokhy/Nidhi Sharma.jpg?s=228x223',
#  'https://grras.com/files/xcxagzwtcpm8xusgf9ga/Harshad Rana.jpg?s=228x223',
#  'https://grras.com/files/z1t5x5siktlaf0ysxeaf/Sachin Yadav.jpg?s=228x223',
# ...

# %%
req = requests.get('https://www.setaswall.com/wp-content/uploads/2018/04/Abstract-Colors-Wallpaper-1080x2280-380x802.jpg')

# %%
req
# Out:
# <Response [200]>

# %%
pwd
# Out:
# 'C:\\Users\\BHARAT\\Desktop\\Python'

# %%
file = open('image.jpg','wb')
file.write(req.content)
file.close()

# %%
c = 1
for var in link:
    filename = 'image' + str(c) + '.jpg'
    req = requests.get(var)
    c += 1
    if req.status_code == 200:
        with open(filename,'wb') as fp:
            fp.write(req.content)
            fp.close()

# %%
req = requests.get('http://www.wiseoldsayings.com/life-quotes/')

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.text,'lxml')

# %%
t = []
for var in soup.findAll('b'):
    t.append(var)

# %%
data = soup.find_all('b')[1::2]

# %%
for var in soup.findAll('b')[1::2]:
    print(var.text)
# Out:
# In the end, it's not the years in your life that count. It's the life in your years.
# Life is inherently risky. There is only one big risk you should avoid at all costs, and that is the risk of doing nothing.
# Life isn't about finding yourself. Life is about creating yourself.
# I have found that if you love life, life will love you back.
# We all have two lives. The second one starts when we realize we only have one.
# You get in life what you have the courage to ask for.
# Life is really simple, but we insist on making it complicated.
# An unexamined life is not worth living.
# When one door closes, another opens; but we often look so long and so regretfully upon the closed door that we do not see the one that has opened for us.
# To live is the rarest thing in the world. Most people exist, that is all.
# Life is what happens to you while you're busy making other plans.
# To live is so startling it leaves little time for anything else.
# ...

# %%
t = []
for tex in soup.findAll('b')[1::2]:
    t.extend(tex)

# %%
print(*t,sep='\n')
# Out:
# In the end, it's not the years in your life that count. It's the life in your years.
# Life is inherently risky. There is only one big risk you should avoid at all costs, and that is the risk of doing nothing.
# Life isn't about finding yourself. Life is about creating yourself.
# I have found that if you love life, life will love you back.
# We all have two lives. The second one starts when we realize we only have one.
# You get in life what you have the courage to ask for.
# Life is really simple, but we insist on making it complicated.
# An unexamined life is not worth living.
# When one door closes, another opens; but we often look so long and so regretfully upon the closed door that we do not see the one that has opened for us.
# To live is the rarest thing in the world. Most people exist, that is all.
# Life is what happens to you while you're busy making other plans.
# To live is so startling it leaves little time for anything else.
# ...
